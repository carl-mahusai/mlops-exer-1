# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("spam-experiment")

# %%
import torch
import torch.nn as nn

# %%
class SPAMData:
    """This handles loading spam data
    """

    def __init__(self):
        return
    
    def prepare_data(self):
        return
