# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("spam-experiment")
# Out:
# <Experiment: artifact_location='/mnt/c/Users/user/Documents/Projects/mlops-exer-1/notebooks/mlruns/1', creation_time=1780870563650, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1780870563650, lifecycle_stage='active', name='spam-experiment', tags={}, trace_location=None, workspace='default'>

# %%
from spam_checker.data.spam_data_module import SPAMDataModule

# %%
spam_data = SPAMDataModule()

# %%
spam_data.prepare_data()
# Out:
# {'filename': 'spam-csv.zip', 'sha-256': '3e05b8e6e1e8fc9aef3ca69399a1bf3849a22084c8401d5d5d592e6c9a0e422b', 'url': 'https://www.kaggle.com/api/v1/datasets/download/uciml/sms-spam-collection-dataset'}
# Unzipping spam...
